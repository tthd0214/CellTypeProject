# %%
#Data Acquisition
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET
from xml.dom import minidom


# Download mouse data in Allen Cell types database

from allensdk.core.cell_types_cache import CellTypesCache
from allensdk.api.queries.cell_types_api import CellTypesApi
import allensdk.brain_observatory.stimulus_info as stim_info
from allensdk.api.queries.rma_api import RmaApi

ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# Download all the data from mice specificially
mouse_df = pd.DataFrame(ctc.get_cells(species=[CellTypesApi.MOUSE]))
mouse_df = mouse_df.set_index('id')
ephys_features = pd.DataFrame(ctc.get_ephys_features()).set_index('specimen_id')
mouse_ephys_df = mouse_df.join(ephys_features, how ='inner')
ephys_columns = list(ephys_features.columns)
ephys_columns
# Out:
# ['adaptation',
#  'avg_isi',
#  'electrode_0_pa',
#  'f_i_curve_slope',
#  'fast_trough_t_long_square',
#  'fast_trough_t_ramp',
#  'fast_trough_t_short_square',
#  'fast_trough_v_long_square',
#  'fast_trough_v_ramp',
#  'fast_trough_v_short_square',
#  'has_burst',
#  'has_delay',
#  'has_pause',
#  'id',
#  'input_resistance_mohm',
#  'latency',
#  'peak_t_long_square',
#  'peak_t_ramp',
#  'peak_t_short_square',
#  'peak_v_long_square',
#  'peak_v_ramp',
#  'peak_v_short_square',
#  'rheobase_sweep_id',
#  'rheobase_sweep_number',
#  'ri',
#  'sag',
#  'seal_gohm',
#  'slow_trough_t_long_square',
#  'slow_trough_t_ramp',
#  'slow_trough_t_short_square',
#  'slow_trough_v_long_square',
#  'slow_trough_v_ramp',
#  'slow_trough_v_short_square',
#  'tau',
#  'threshold_i_long_square',
#  'threshold_i_ramp',
#  'threshold_i_short_square',
#  'threshold_t_long_square',
#  'threshold_t_ramp',
#  'threshold_t_short_square',
#  'threshold_v_long_square',
#  'threshold_v_ramp',
#  'threshold_v_short_square',
#  'thumbnail_sweep_id',
#  'trough_t_long_square',
#  'trough_t_ramp',
#  'trough_t_short_square',
#  'trough_v_long_square',
#  'trough_v_ramp',
#  'trough_v_short_square',
#  'upstroke_downstroke_ratio_long_square',
#  'upstroke_downstroke_ratio_ramp',
#  'upstroke_downstroke_ratio_short_square',
#  'vm_for_sag',
#  'vrest']

# %%
visal_ephys_data = mouse_ephys_df[mouse_ephys_df["structure_area_abbrev"] == "VISal"]
visal_ephys_data
# Out:
#           reporter_status                                 cell_soma_location  \
# 484744672        positive  [8203.758961728, 1615.87732782576, 9067.378972...
# 562432852        positive       [8600.0, 1708.27912478957, 1529.31909992203]
# 585841870        positive  [8067.38063946462, 1492.96455692423, 9584.7270...
# 596619013        positive  [8493.48348400922, 1696.71284087851, 2140.9817...
# 547330489        positive  [8113.23628444788, 2048.55785836426, 9324.7373...
# 569412397        positive         [8500.0, 1352.6396572646, 9519.1387167368]
# 327997484        positive  [8434.07046477002, 1552.52142292377, 9012.0739...
# 581741836        positive  [7937.54525096976, 1802.75706262253, 2204.4458...
# 574968354        positive  [8389.99999999999, 1579.99129319907, 9332.1190...
# 487099387        positive  [7904.34925323456, 1605.47148548097, 9504.3033...
# 579660456        positive  [8390.50931941066, 2121.06739733666, 2204.9235...
# 485060618        positive  [8570.00000000001, 1612.43988652858, 9556.6157...
# 583804142        positive  [8303.53952227147, 1660.25655319368, 9147.2401...
# 475625477        positive  [8136.16410693952, 1527.98863472354, 1823.6506...
# 584682764        positive  [8004.25113952081, 1498.88927223733, 9607.0527...
# 569072334        positive  [8250.80321939769, 1422.37797440341, 1897.1919...
# 321923685        positive        [8516.0, 1941.3690772043, 1726.47900083613]
#
#                 species                                               name  \
# 484744672  Mus musculus                Pvalb-IRES-Cre;Ai14-201773.05.01.01
# 562432852  Mus musculus              Ndnf-IRES2-dgCre;Ai14-290386.04.02.01
# 585841870  Mus musculus  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-315067.0...
# 596619013  Mus musculus  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-329540.0...
# 547330489  Mus musculus    Nos1-CreERT2;Sst-IRES-FlpO;Ai65-271574.05.01.02
# 569412397  Mus musculus              Ndnf-IRES2-dgCre;Ai14-298344.05.01.01
# 327997484  Mus musculus               Htr3a-Cre_NO152;Ai14-175482.06.01.01
# 581741836  Mus musculus                Esr2-IRES2-Cre;Ai14-311708.06.02.01
# 574968354  Mus musculus               Htr3a-Cre_NO152;Ai14-306200.06.01.01
# 487099387  Mus musculus               Htr3a-Cre_NO152;Ai14-209863.05.01.01
# 579660456  Mus musculus               Vipr2-IRES2-Cre;Ai14-310515.05.02.01
# 485060618  Mus musculus                Pvalb-IRES-Cre;Ai14-202466.05.01.01
# 583804142  Mus musculus               Htr3a-Cre_NO152;Ai14-314135.05.01.01
# 475625477  Mus musculus               Htr3a-Cre_NO152;Ai14-185555.05.02.01
# 584682764  Mus musculus                  Oxtr-T2A-Cre;Ai14-314784.06.01.01
# 569072334  Mus musculus               Vipr2-IRES2-Cre;Ai14-297026.05.02.01
# 321923685  Mus musculus                     Nr5a1-Cre;Ai14-172512.06.02.01
#
#           structure_layer_name  structure_area_id structure_area_abbrev  \
# 484744672                    5                402                 VISal
# 562432852                    1                402                 VISal
# 585841870                  2/3                402                 VISal
# 596619013                    5                402                 VISal
# 547330489                   6a                402                 VISal
# 569412397                    1                402                 VISal
# 327997484                    5                402                 VISal
# 581741836                    5                402                 VISal
# 574968354                    4                402                 VISal
# 487099387                  2/3                402                 VISal
# 579660456                   6b                402                 VISal
# 485060618                  2/3                402                 VISal
# 583804142                    5                402                 VISal
# 475625477                  2/3                402                 VISal
# 584682764                  2/3                402                 VISal
# 569072334                  2/3                402                 VISal
# 321923685                    4                402                 VISal
#
#                             transgenic_line dendrite_type  apical  ...  \
# 484744672                    Pvalb-IRES-Cre        aspiny      NA  ...
# 562432852                  Ndnf-IRES2-dgCre        aspiny      NA  ...
# 585841870  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre        aspiny      NA  ...
# 596619013  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre        aspiny      NA  ...
# 547330489        Nos1-CreERT2|Sst-IRES-FlpO        aspiny      NA  ...
# 569412397                  Ndnf-IRES2-dgCre        aspiny      NA  ...
# 327997484                   Htr3a-Cre_NO152        aspiny      NA  ...
# 581741836                    Esr2-IRES2-Cre         spiny  intact  ...
# 574968354                   Htr3a-Cre_NO152        aspiny      NA  ...
# 487099387                   Htr3a-Cre_NO152        aspiny      NA  ...
# 579660456                   Vipr2-IRES2-Cre        aspiny      NA  ...
# 485060618                    Pvalb-IRES-Cre        aspiny      NA  ...
# 583804142                   Htr3a-Cre_NO152        aspiny      NA  ...
# 475625477                   Htr3a-Cre_NO152        aspiny      NA  ...
# 584682764                      Oxtr-T2A-Cre         spiny  intact  ...
# 569072334                   Vipr2-IRES2-Cre        aspiny      NA  ...
# 321923685                         Nr5a1-Cre        aspiny      NA  ...
#
#           trough_t_ramp trough_t_short_square  trough_v_long_square  \
# 484744672           NaN              1.464800            -68.062508
# 562432852      4.167650              1.280900            -50.500000
# 585841870      9.261233              1.388944            -55.156254
# 596619013      7.940227              1.348125            -59.343750
# 547330489      2.435807              1.935725            -55.500004
# 569412397      5.232760              1.059445            -54.250000
# 327997484      8.027857              1.301524            -56.843750
# 581741836      7.512707              1.658000            -46.093750
# 574968354      2.633500              1.563800            -52.218754
# 487099387      2.942097              1.530804            -55.343750
# 579660456      4.927590              1.446144            -59.687504
# 485060618     24.587112              1.209065            -56.250004
# 583804142      6.337900              1.758125            -54.437504
# 475625477      3.406125              1.616696            -46.593750
# 584682764     12.553960              1.519172            -56.468750
# 569072334      4.593684              1.309077            -49.593754
# 321923685     11.073493              1.554089            -60.531250
#
#           trough_v_ramp  trough_v_short_square  \
# 484744672           NaN             -72.812501
# 562432852    -50.812504             -77.156250
# 585841870    -52.427086             -77.106252
# 596619013    -55.885417             -72.531253
# 547330489    -55.968754             -73.531254
# 569412397    -55.635420             -66.164068
# 327997484    -55.833335             -76.081252
# 581741836    -50.385420             -67.406250
# 574968354    -46.875001             -68.843755
# 487099387    -56.718751             -65.756252
# 579660456    -58.312504             -78.487506
# 485060618    -60.635420             -78.112505
# 583804142    -54.906254             -71.773441
# 475625477    -46.000003             -67.244795
# 584682764    -55.760420             -81.225003
# 569072334    -49.581251             -70.084826
# 321923685    -52.479168             -72.382816
#
#            upstroke_downstroke_ratio_long_square  \
# 484744672                               1.094022
# 562432852                               2.990029
# 585841870                               1.567973
# 596619013                               1.745440
# 547330489                               2.499719
# 569412397                               2.417882
# 327997484                               3.860129
# 581741836                               3.913028
# 574968354                               4.221441
# 487099387                               2.476665
# 579660456                               1.347305
# 485060618                               1.119367
# 583804142                               3.706756
# 475625477                               2.347381
# 584682764                               4.995051
# 569072334                               1.673971
# 321923685                               1.557328
#
#            upstroke_downstroke_ratio_ramp  \
# 484744672                             NaN
# 562432852                        3.077481
# 585841870                        1.463224
# 596619013                        1.563598
# 547330489                        2.489419
# 569412397                        2.533214
# 327997484                        4.110745
# 581741836                        4.088246
# 574968354                        2.856950
# 487099387                        2.125824
# 579660456                        1.380882
# 485060618                        1.148667
# 583804142                        3.781745
# 475625477                        2.069299
# 584682764                        4.893752
# 569072334                        1.689099
# 321923685                        1.374809
#
#            upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# 484744672                                1.233001  -96.156258 -72.188530
# 562432852                                2.456566 -100.968758 -77.090721
# 585841870                                1.586733  -89.656258 -76.741241
# 596619013                                1.787207  -94.906258 -71.855003
# 547330489                                1.819711  -99.718758 -72.544563
# 569412397                                2.284881  -85.562508 -65.663780
# 327997484                                2.589110  -87.250000 -75.801476
# 581741836                                4.611910  -92.156250 -67.348328
# 574968354                                3.961055  -99.750008 -69.849701
# 487099387                                2.579849  -93.625000 -64.676910
# 579660456                                1.384675  -90.875008 -78.031349
# 485060618                                1.213796  -89.218750 -77.294884
# 583804142                                2.974483  -78.218750 -71.292038
# 475625477                                2.389602  -94.218750 -66.155899
# 584682764                                4.290907  -89.468758 -81.185852
# 569072334                                1.744368  -90.187508 -69.308357
# 321923685                                1.648069  -84.687500 -72.372963
#
# [17 rows x 70 columns]

# %%
vispm_ephys_data = mouse_ephys_df[mouse_df["structure_area_abbrev"] == "VISpm"]
vispm_ephys_data
# Out:
#           reporter_status                                 cell_soma_location  \
# 585805211        positive  [8407.15289790015, 492.783868238398, 7441.8603...
# 586073850        positive  [8342.51450936423, 483.96335916196, 7456.01971...
# 565120091        positive       [8630.0, 718.644455855271, 4020.89860787752]
# 590558808        positive  [8342.51450936424, 1165.05758154957, 4176.2371...
# 466827702        positive  [8485.50040095049, 781.577357685944, 7461.2991...
# ...                   ...                                                ...
# 570098371        positive         [8965.0, 701.438224382355, 7254.565954545]
# 570081024        positive       [9000.0, 487.117935039925, 4152.00604827901]
# 592868444        positive  [8640.57620175549, 982.335480880878, 4303.7869...
# 501847408        positive  [8640.57620175548, 844.63702838597, 7249.39457...
# 479770916        negative  [7943.68994090724, 891.295645214414, 3778.0868...
#
#                 species                                               name  \
# 585805211  Mus musculus  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-315067.0...
# 586073850  Mus musculus  Vipr2-IRES2-Cre;Slc32a1-T2A-FlpO;Ai65-315072.0...
# 565120091  Mus musculus              Ndnf-IRES2-dgCre;Ai14-292670.04.02.01
# 590558808  Mus musculus               Vipr2-IRES2-Cre;Ai14-316908.04.02.01
# 466827702  Mus musculus                Scnn1a-Tg3-Cre;Ai14-180211.05.01.01
# ...                 ...                                                ...
# 570098371  Mus musculus                Pvalb-IRES-Cre;Ai14-299332.04.01.01
# 570081024  Mus musculus                  Vip-IRES-Cre;Ai14-298226.03.02.01
# 592868444  Mus musculus                  Vip-IRES-Cre;Ai14-322778.05.02.01
# 501847408  Mus musculus              Rorb-IRES2-Cre-D;Ai14-228832.03.01.01
# 479770916  Mus musculus              Rorb-IRES2-Cre-D;Ai14-196664.06.02.01
#
#           structure_layer_name  structure_area_id structure_area_abbrev  \
# 585805211                  2/3                533                 VISpm
# 586073850                  2/3                533                 VISpm
# 565120091                    4                533                 VISpm
# 590558808                   6b                533                 VISpm
# 466827702                    5                533                 VISpm
# ...                        ...                ...                   ...
# 570098371                    4                533                 VISpm
# 570081024                  2/3                533                 VISpm
# 592868444                   6a                533                 VISpm
# 501847408                    5                533                 VISpm
# 479770916                    5                533                 VISpm
#
#                             transgenic_line   dendrite_type     apical  ...  \
# 585805211  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre          aspiny         NA  ...
# 586073850  Slc32a1-T2A-FlpO|Vipr2-IRES2-Cre          aspiny         NA  ...
# 565120091                  Ndnf-IRES2-dgCre  sparsely spiny         NA  ...
# 590558808                   Vipr2-IRES2-Cre          aspiny         NA  ...
# 466827702                    Scnn1a-Tg3-Cre           spiny  truncated  ...
# ...                                     ...             ...        ...  ...
# 570098371                    Pvalb-IRES-Cre          aspiny         NA  ...
# 570081024                      Vip-IRES-Cre          aspiny         NA  ...
# 592868444                      Vip-IRES-Cre          aspiny         NA  ...
# 501847408                    Rorb-IRES2-Cre           spiny     intact  ...
# 479770916                    Rorb-IRES2-Cre           spiny     intact  ...
#
#           trough_t_ramp trough_t_short_square  trough_v_long_square  \
# 585805211      9.659467              1.476420            -53.843750
# 586073850      8.524820              1.473915            -51.031254
# 565120091      3.258653              1.486095            -53.906250
# 590558808     11.425380              1.626560            -66.500000
# 466827702      3.228553              1.677151            -54.218754
# ...                 ...                   ...                   ...
# 570098371     10.054427              1.475297            -56.312500
# 570081024      3.454687              1.443135            -54.218754
# 592868444      2.345967              1.695680            -52.937504
# 501847408      4.398667              1.524467            -62.375000
# 479770916      6.398125              1.065298            -56.468750
#
#           trough_v_ramp  trough_v_short_square  \
# 585805211    -50.020836             -78.343758
# 586073850    -50.500001             -73.257812
# 565120091    -55.031253             -72.882818
# 590558808    -63.703127             -73.445312
# 466827702    -56.812504             -83.507818
# ...                 ...                    ...
# 570098371    -53.145837             -71.906251
# 570081024    -52.822918             -66.507814
# 592868444    -52.156251             -76.958336
# 501847408    -56.947919             -79.187505
# 479770916    -56.958336             -69.666672
#
#            upstroke_downstroke_ratio_long_square  \
# 585805211                               1.535442
# 586073850                               1.536400
# 565120091                               1.782950
# 590558808                               1.379419
# 466827702                               3.668244
# ...                                          ...
# 570098371                               1.378072
# 570081024                               2.307847
# 592868444                               2.697617
# 501847408                               3.685257
# 479770916                               2.490573
#
#            upstroke_downstroke_ratio_ramp  \
# 585805211                        1.384049
# 586073850                        1.470371
# 565120091                        1.780164
# 590558808                        1.305893
# 466827702                        4.060813
# ...                                   ...
# 570098371                        1.074558
# 570081024                        2.388018
# 592868444                        2.572670
# 501847408                        3.607356
# 479770916                        2.506231
#
#            upstroke_downstroke_ratio_short_square  vm_for_sag      vrest
# 585805211                                1.553318  -89.906250 -77.756340
# 586073850                                1.614207  -87.593758 -72.989372
# 565120091                                1.866246  -99.875000 -71.803574
# 590558808                                1.438236  -83.031250 -73.077560
# 466827702                                3.561467 -100.218758 -82.750099
# ...                                           ...         ...        ...
# 570098371                                1.496736  -84.781250 -70.649605
# 570081024                                2.343220  -98.906258 -65.818382
# 592868444                                2.792635  -98.937508 -76.646423
# 501847408                                3.705048  -95.500008 -78.724121
# 479770916                                2.369874  -78.312500 -67.626282
#
# [89 rows x 70 columns]
